# %% [markdown]
# # <center> DNN

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %% [markdown]
# ## Get Data

# %%
# numpy data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train[..., np.newaxis] / 255.0


def filter_pair(x, y, a, b):
    keep = (y == a) | (y == b)
    x, y = x[keep], y[keep]
    y = y == a
    return x, y


x_train, y_train = filter_pair(x_train, y_train, 1, 5)  # classify 1, 5 only
x_train_small = tf.image.resize(x_train, (4, 4)).numpy()
x_train_bin = np.array(x_train_small > 0.5, dtype=np.float32)  # binary input
x_train_bin = np.squeeze(x_train_bin)[:10000]

# tensorflow data
x_train_tf = tf.reshape(tf.constant(x_train_bin, dtype=tf.float64), [-1, 16])
y_train_tf = tf.constant(y_train[:10000], dtype=tf.float64)

# %% [markdown]
# ## CNN model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(5, activation="relu"),
    tf.keras.layers.Dense(2, activation="relu"),
    tf.keras.layers.Dense(1, activation="relu")
    ])

# %% [markdown]
# ## train

# %%
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(0.005),
    metrics=[tf.keras.metrics.BinaryAccuracy()],
)

history = model.fit(x_train_tf, y_train_tf, batch_size=100, epochs=30, shuffle=True)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.7308 - binary_accuracy: 0.6512
# Epoch 2/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.4380 - binary_accuracy: 0.8598
# Epoch 3/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3798 - binary_accuracy: 0.8670
# Epoch 4/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3941 - binary_accuracy: 0.8698
# Epoch 5/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3766 - binary_accuracy: 0.8702
# Epoch 6/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3726 - binary_accuracy: 0.8678
# Epoch 7/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3736 - binary_accuracy: 0.8693
# Epoch 8/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3722 - binary_accuracy: 0.8701
# Epoch 9/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3753 - binary_accuracy: 0.8705
# Epoch 10/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3794 - binary_accuracy: 0.8713
# Epoch 11/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3725 - binary_accuracy: 0.8707
# Epoch 12/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3704 - binary_accuracy: 0.8715
# Epoch 13/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3688 - binary_accuracy: 0.8716
# Epoch 14/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3640 - binary_accuracy: 0.8718
# Epoch 15/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3650 - binary_accuracy: 0.8769
# Epoch 16/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3659 - binary_accuracy: 0.8758
# Epoch 17/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.3637 - binary_accuracy: 0.8774
# Epoch 18/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3660 - binary_accuracy: 0.8779
# Epoch 19/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3600 - binary_accuracy: 0.8779
# Epoch 20/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3674 - binary_accuracy: 0.8780
# Epoch 21/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3650 - binary_accuracy: 0.8780
# Epoch 22/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3723 - binary_accuracy: 0.8745
# Epoch 23/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3610 - binary_accuracy: 0.8780
# Epoch 24/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3588 - binary_accuracy: 0.8779
# Epoch 25/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3590 - binary_accuracy: 0.8780
# Epoch 26/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3716 - binary_accuracy: 0.8776
# Epoch 27/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3684 - binary_accuracy: 0.8776
# Epoch 28/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3614 - binary_accuracy: 0.8780
# Epoch 29/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3652 - binary_accuracy: 0.8777
# Epoch 30/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.3634 - binary_accuracy: 0.8776

# %% [markdown]
# ## plot

# %%
acc = history.history['binary_accuracy']
loss = history.history['loss']

plt.plot(acc, label='Training Accuracy')
plt.plot(loss, label='Training Loss')
plt.legend()
plt.show()
